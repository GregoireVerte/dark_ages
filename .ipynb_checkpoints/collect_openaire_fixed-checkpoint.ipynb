# %%
import requests
import pandas as pd
import time
from datetime import datetime

def get_openaire_articles(keywords, page_size=25, max_pages=2, open_access_only=True):
    """
    Pobiera artykuły z OpenAIRE Search API (używając 'keywords' zamiast 'query').
    """
    print(f"Rozpoczynam pobieranie dla słów kluczowych (Search API): '{keywords}'...")
    
    # Poprawny endpoint
    base_url = "https://api.openaire.eu/search/publications"
    
    all_records = []
    current_page = 1
    
    for page in range(1, max_pages + 1):
        params = {
            "keywords": keywords,  ### Zmienione z 'query'
            "size": page_size,
            "page": current_page,  ### Paginacja przez page (1-based)
        }
        if open_access_only:
            params["openAccessColor"] = "gold"  # tylko otwarte publikacje, pełne Open Access (bezpieczne prawnie)
            params["format"] = "json" # odpowiedź w JSON (łatwiejsze parsowanie)
        
        print(f"  > Wysyłane parametry: {params}")
        
        try:
            response = requests.get(base_url, params=params, headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'})
            response.raise_for_status()
            
            data = response.json()
            # print(f"  > DEBUG JSON: {str(data)[:200]}...")

            response_part = data.get('response', {})
            
            results = response_part.get('results', {})

            ## zabezpieczenie: Czasem API zwraca None zamiast {} gdy nie ma wyników na danej stronie
            if results is None:
                print(f"  > Brak dalszych wyników na stronie {page} (koniec).")
                break

            raw_records = results.get('result', [])
            

            ### OpenAIRE API jest dziwne: jak jest 1 wynik to zwraca dict, jak więcej to listę ### trzeba to ujednolicić do listy:
            if isinstance(raw_records, dict):
                records = [raw_records]
            elif isinstance(raw_records, list):
                records = raw_records
            else:
                records = []
                
            
            if not records:
                print(f"  > Brak rekordów (struktura pusta).")
                break
                
            print(f"  > Znaleziono {len(records)} rekordów na stronie {page}.")
                
            for record in records:
                try:
                    oaf_result = record.get('metadata', {}).get('oaf:entity', {}).get('oaf:result', {})

                    # Tytuł
                    title = ''
                    title_list = oaf_result.get('title', [])
                    if title_list and isinstance(title_list, list):
                        first = title_list[0]
                        title = first if isinstance(first, str) else (first.get('$', '') if isinstance(first, dict) else '')
                    elif isinstance(title_list, dict): # czasem tytuł to dict
                        title = title_list.get('$', '')
                    
                    # Abstrakt (description -> często string lub dict)
                    abstract = ''
                    desc = oaf_result.get('description', '')
                    if isinstance(desc, str):
                        abstract = desc
                    elif isinstance(desc, dict):
                        abstract = desc.get('$', '')

                    # Fallback na abstract (rzadko)
                    if not abstract:
                        abs_list = oaf_result.get('abstract', [])
                        if abs_list and isinstance(abs_list, list):
                            first = abs_list[0]
                            abstract = first if isinstance(first, str) else (first.get('$', '') if isinstance(first, dict) else '')
                    
                    # Rok
                    pub_date = oaf_result.get('dateofacceptance', '') or (oaf_result.get('relevantdate', [{}])[0].get('$', '') if oaf_result.get('relevantdate') else '')
                    year = pub_date[:4] if pub_date and isinstance(pub_date, str) else ''
                    if isinstance(pub_date, dict): year = pub_date.get('$', '')[:4]
                    
                    # Licencja
                    access = oaf_result.get('bestaccessright', {})
                    license_name = access.get('@classid', '') if isinstance(access, dict) else ''
                    
                    # Link
                    link = ''
                    instances = oaf_result.get('children', {}).get('instance', [])
                    if instances and isinstance(instances, list) and len(instances) > 0:
                        webresources = instances[0].get('webresource', [])
                        # czasem webresource to lista, czasem dict
                        if isinstance(webresources, list) and len(webresources) > 0:
                            url_obj = webresources[0].get('url', {})
                            link = url_obj if isinstance(url_obj, str) else (url_obj.get('$', '') if isinstance(url_obj, dict) else '')
                        elif isinstance(webresources, dict):
                             url_obj = webresources.get('url', {})
                             link = url_obj if isinstance(url_obj, str) else (url_obj.get('$', '') if isinstance(url_obj, dict) else '')

                    # Fallback: DOI
                    if not link:
                        pid_list = oaf_result.get('pid', [])
                        # pid_list może być dictem jeśli jest tylko jeden PID
                        if isinstance(pid_list, dict): pid_list = [pid_list]
                        
                        if isinstance(pid_list, list):
                            for pid in pid_list:
                                if isinstance(pid, dict) and pid.get('@classid') == 'doi':
                                    doi = pid.get('$', '')
                                    if doi:
                                        link = f"https://doi.org/{doi}"
                                        break
                    
                    # Journal title
                    source = oaf_result.get('source', '')
                    journal_title = ''
                    if isinstance(source, str):
                        journal_title = source
                    elif isinstance(source, list) and len(source) > 0:
                        journal_title = source[0] if isinstance(source[0], str) else (source[0].get('$', '') if isinstance(source[0], dict) else '')

                    # Authors
                    authors_str = ""
                    creators = oaf_result.get('creator', [])
                    
                    authors_list = []
                    ## przypadek 1: lista autorów
                    if isinstance(creators, list):
                        for c in creators:
                            if isinstance(c, dict):
                                ### imię i nazwisko jest zazwyczaj pod kluczem '$'
                                name = c.get('$', '')
                                if name:
                                    authors_list.append(name)
                            elif isinstance(c, str):
                                authors_list.append(c)
                    
                    ## przypadek 2: pojedynczy autor (dict)
                    elif isinstance(creators, dict):
                        name = creators.get('$', '')
                        if name:
                            authors_list.append(name)
                    
                    ## przypadek 3: pojedynczy autor (str)
                    elif isinstance(creators, str):
                        authors_list.append(creators)

                    ## łączenie średnikami
                    authors_str = "; ".join(authors_list)
                    
                    # dodaje tylko jesli jest abstract
                    if abstract and abstract.strip():
                        all_records.append({
                            "keywords": keywords,
                            "title": title.strip() if title else "",
                            "creator": authors_str,
                            "abstract": abstract.strip(),
                            "year": year,
                            "journal_title": journal_title,
                            "license": license_name,
                            "link": link or "",
                            "query": keywords
                        })

                except Exception as e:
                    print(f"  > Błąd parsowania rekordu: {e}")
                    continue
            
            current_page += 1
            
        except requests.exceptions.RequestException as e:
            print(f"Błąd sieci: {e}")
            break
        
        # przerwa między stronami
        time.sleep(2)
    
    print(f"Pobrano {len(all_records)} artykułów z abstraktami dla słów kluczowych: '{keywords}'.")
    return all_records

# Główna część skryptu
if __name__ == "__main__":
    
    KEYWORDS_TO_SEARCH = [
        "ayyubid",
        "fall of rome",
        "sack of rome 410",
        "sack of rome 455",
        "battle of chalons",
        "theoderic",
        "justinian reconquest",
        "plague of justinian",
        "maurice strategikon",
        "byzantine empire 5th century",
        "western roman empire collapse",
        "romanitas",
        "transformation of the roman world",
        "pirenne thesis",
        "romano-germanic kingdoms",
        "post-roman",
        "sub-roman britain",
        "anglo-saxon settlement",
        "frisian migration",
        "slavic expansion",
        "avar khaganate",
        "lombard italy",
        "cassiodorus",
        "jordanes",
        "gregory of tours",
        "isidore of seville",
        "roman law codification",
        "theodosian code",
        "salic law",
        "gothic spain",
        "alan kingdom",
        "vandal africa",
        "roman identity 5th-7th",
        "early medieval history",
        "barbarian migrations", 
        "vikings", 
        "carolingian",
        "merovingian",
        "early middle ages",
        "byzantium",
        "dark ages",
        "anglo-saxon history",
        "saxons",
        "angles in britannia",
        "jutes",
        "early slavs",
        "romano-britons",
        "romano-british",
		"huns history",
		"history huns",
		"white huns",
		"black huns",
        "goths",
        "ostrogoths",
        "visigoths",
        "history franks",
		"franks history",
        "alemanni history",
		"history alemanni",
        "vandals history",
        "gepids",
        "lombards",
        "attila",
        "thuringians",
        "rugians",
        "sciri",
        "herules",
        "bavarians history",
        "avars history",
        "burgundians",
        "viking",
        "germanic paganism",
        "slavic paganism",
        "medieval celts",
        "norse paganism",
        "foederati",
        "roman britannia",
        "suebi history",
        "alans history",
		"history alans",
        "frisians",
        "sarmatians",
        "period 400-1000",
        "late roman empire",
        "barbarian kingdoms",
        "arianism christianity",
        "magyars",
        "khazar",
		"khazars",
        "umayyad",
        "charlemagne",
        "clovis",
        "theodoric the great",
        "medieval constantinople",
        "gothic war",
        "barbarian invasions",
        "rome imperial borders",
        "late antiquity",
        "alaric",
        "fall of the western roman empire",
        "imperial restoration",
        "justinian",
        "odoacer",
        "christianization",
        "migration period",
        "eastern roman empire",
        "medieval rome",
        "early bulgars",
        "danelag",
		"danelaw",
        "visigothic spain",
        "king arthur history",
        "norman kingdom",
		"hephthalite",
		"ephthalite",
		"ebodalo",
        "nomadic empire",
        "kidarites",
        "alchon huns",
        "kushan",
        "rouran",
        "xianbei",
        "xiongnu",
        "yuezhi",
        "saka people",
        "chionites",
        "bactria",
        "roman gaul",
        "sasanian",
        "persian empire",
        "latin empire",
        "early danes",
        "beowulf",
        "roman civil wars",
        "crossing of the rhine",
        "rome imperial government",
        "barbarian rulers",
        "roman heritage",
        "roman emperors",
        "nicene christianity",
        "gothic kingdoms",
        "han dynasty",
        "tang china",
        "roman usurpers",
        "magister militum",
        "late roman army",
        "picts",
        "dal riada",
		"dal riata",
		"dalriada",
        "gaelic tribes",
        "heptarchy",
        "bretwalda",
        "old english period",
        "kingdom of east anglia",
        "germanic settlement",
        "geats",
		"vistula venedi",
        "venedi slavs",
        "wends history",
        "sclaveni",
        "antes slavs",
        "norsemen",
        "balto-slavic",
        "proto-slavic",
        "slavic settlement",
        "getica",
        "jordanes",
        "sarmatae",
        "widsith",
        "king samo",
		"samo empire",
        "volga bulgaria",
        "varangian",
        "old great bulgaria",
        "crusades",
        "saqaliba",
        "golden horde",
        "kara-khanid",
        "seljuk",
        "kara khitai",
        "great liao",
        "khitan",
        "kipchak",
        "qangli",
        "kangly",
        "cumans history",
        "pechenegs",
        "karluks",
        "gokturks",
        "hazaras",
        "chagatai",
        "turco-mongol",
        "ilkhanate",
        "timurids",
        "jalayirid",
        "sultanate of rum",
        "turco-persian",
        "anatolian beyliks",
        "cilician armenia",
        "empire of trebizond",
        "yuan china",
        "hunnic empire",
        "vistula veneti",
        "karamanids",
        "aq qoyunlu",
        "mamluks",
        "qara qoyunlu",
        "teke beylik",
        "aydin beylik",
        "menteshe",
        "danishmend",
        "mengujekids",
        "saltukids",
        "kayi tribe",
        "ghaznavids",
        "great moravia",
        "kievan rus",
        "baltic slavic piracy",
        "rashidun caliphate",
        "abbasid",
        "muslim conquest of persia",
        "muslim conquest of the levant",
        "emperor heraclius",
        "muslim conquest of egypt",
        "muslim conquest of maghreb",
        "ghassanids",
        "lakhmids",
        "assyrian church",
        "nestorians",
        "paulicianism",
        "bogomilism",
        "tondrakians",
        "himyar",
        "lotharingia",
        "neustria",
        "austrasia",
        "kingdom of soissons",
        "ambrosius aurelianus",
        "gildas",
        "arthurian period",
        "de excidio et conquestu britanniae",
        "medieval brittany",
        "kingdom of galicia",
        "marcomanni",
        "marcus aurelius",
        "ricimer",
        "aetius",
        "majorian",
        "aegidius",
        "syagrius",
        "crisis of third century",
        "constantine the great",
        "catalaunian plains",
        "ripuarian franks",
        "salian franks",
        "ammianus marcellinus",
        "burgundy history",
		"history burgundy",
        "strategikon",
        "roxolani",
        "iazyges",
        "sabirs",
        "onoghurs",
        "utigurs",
        "kutrigurs",
        "akatziri",
        "barsils",
        "mishar tatars",
        "mordvins",
        "qaraqalpaqs",
        "nogai horde",
        "bashkirs",
        "tengrism",
        "uyghur khaganate",
        "yenisei kyrgyz",
    ]
    
    ARTICLES_PER_KEYWORD = 50
    MAX_PAGES_PER_KEYWORD = 3  # do 150 wyników na keyword
    
    all_articles_data = []
    
    print("Rozpoczynam zbieranie danych z OpenAIRE (Search API)...")
    
    for keyword in KEYWORDS_TO_SEARCH:
        articles = get_openaire_articles(keyword, page_size=ARTICLES_PER_KEYWORD, max_pages=MAX_PAGES_PER_KEYWORD)
        all_articles_data.extend(articles)
        
        # przerwa między keywordami
        time.sleep(3) 
    
    if all_articles_data:
        df = pd.DataFrame(all_articles_data)
        
        ## output_filename = f"openaire_articles_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
        output_filename = "openaire_articles_updated.csv"
        df.to_csv(output_filename, index=False, encoding='utf-8')
        
        print(f"\nGotowe! Zapisano łącznie {len(df)} artykułów do pliku: {output_filename}")
        print("Przykładowe dane:")
        print(df.head())
    else:
        print("Nie udało się pobrać żadnych artykułów.")
# Out:
# Rozpoczynam zbieranie danych z OpenAIRE (Search API)...
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'ayyubid'...
#   > Wysyłane parametry: {'keywords': 'ayyubid', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'ayyubid', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'ayyubid', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 9 rekordów na stronie 3.
# Pobrano 80 artykułów z abstraktami dla słów kluczowych: 'ayyubid'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'fall of rome'...
#   > Wysyłane parametry: {'keywords': 'fall of rome', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'fall of rome', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'fall of rome', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 3.
# Pobrano 138 artykułów z abstraktami dla słów kluczowych: 'fall of rome'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'sack of rome 410'...
#   > Wysyłane parametry: {'keywords': 'sack of rome 410', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 4 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'sack of rome 410', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 3 artykułów z abstraktami dla słów kluczowych: 'sack of rome 410'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'sack of rome 455'...
#   > Wysyłane parametry: {'keywords': 'sack of rome 455', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 1 (koniec).
# Pobrano 0 artykułów z abstraktami dla słów kluczowych: 'sack of rome 455'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'battle of chalons'...
#   > Wysyłane parametry: {'keywords': 'battle of chalons', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 1 (koniec).
# Pobrano 0 artykułów z abstraktami dla słów kluczowych: 'battle of chalons'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'theoderic'...
#   > Wysyłane parametry: {'keywords': 'theoderic', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 10 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'theoderic', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 5 artykułów z abstraktami dla słów kluczowych: 'theoderic'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'justinian reconquest'...
#   > Wysyłane parametry: {'keywords': 'justinian reconquest', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 3 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'justinian reconquest', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 1 artykułów z abstraktami dla słów kluczowych: 'justinian reconquest'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'plague of justinian'...
#   > Wysyłane parametry: {'keywords': 'plague of justinian', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 41 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'plague of justinian', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 37 artykułów z abstraktami dla słów kluczowych: 'plague of justinian'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'maurice strategikon'...
#   > Wysyłane parametry: {'keywords': 'maurice strategikon', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 2 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'maurice strategikon', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 2 artykułów z abstraktami dla słów kluczowych: 'maurice strategikon'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'byzantine empire 5th century'...
#   > Wysyłane parametry: {'keywords': 'byzantine empire 5th century', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 15 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'byzantine empire 5th century', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 12 artykułów z abstraktami dla słów kluczowych: 'byzantine empire 5th century'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'western roman empire collapse'...
#   > Wysyłane parametry: {'keywords': 'western roman empire collapse', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 29 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'western roman empire collapse', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 25 artykułów z abstraktami dla słów kluczowych: 'western roman empire collapse'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'romanitas'...
#   > Wysyłane parametry: {'keywords': 'romanitas', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'romanitas', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'romanitas', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 3.
# Pobrano 150 artykułów z abstraktami dla słów kluczowych: 'romanitas'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'transformation of the roman world'...
#   > Wysyłane parametry: {'keywords': 'transformation of the roman world', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'transformation of the roman world', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'transformation of the roman world', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 3.
# Pobrano 141 artykułów z abstraktami dla słów kluczowych: 'transformation of the roman world'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'pirenne thesis'...
#   > Wysyłane parametry: {'keywords': 'pirenne thesis', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 3 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'pirenne thesis', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 3 artykułów z abstraktami dla słów kluczowych: 'pirenne thesis'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'romano-germanic kingdoms'...
#   > Wysyłane parametry: {'keywords': 'romano-germanic kingdoms', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 2 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'romano-germanic kingdoms', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 2 artykułów z abstraktami dla słów kluczowych: 'romano-germanic kingdoms'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'post-roman'...
#   > Wysyłane parametry: {'keywords': 'post-roman', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'post-roman', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'post-roman', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 3.
# Pobrano 107 artykułów z abstraktami dla słów kluczowych: 'post-roman'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'sub-roman britain'...
#   > Wysyłane parametry: {'keywords': 'sub-roman britain', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 8 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'sub-roman britain', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 7 artykułów z abstraktami dla słów kluczowych: 'sub-roman britain'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'anglo-saxon settlement'...
#   > Wysyłane parametry: {'keywords': 'anglo-saxon settlement', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 36 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'anglo-saxon settlement', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 31 artykułów z abstraktami dla słów kluczowych: 'anglo-saxon settlement'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'frisian migration'...
#   > Wysyłane parametry: {'keywords': 'frisian migration', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 8 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'frisian migration', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 6 artykułów z abstraktami dla słów kluczowych: 'frisian migration'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'slavic expansion'...
#   > Wysyłane parametry: {'keywords': 'slavic expansion', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Błąd parsowania rekordu: 'NoneType' object has no attribute 'get'
#   > Wysyłane parametry: {'keywords': 'slavic expansion', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Błąd parsowania rekordu: 'NoneType' object has no attribute 'get'
#   > Wysyłane parametry: {'keywords': 'slavic expansion', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 36 rekordów na stronie 3.
# Pobrano 113 artykułów z abstraktami dla słów kluczowych: 'slavic expansion'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'avar khaganate'...
#   > Wysyłane parametry: {'keywords': 'avar khaganate', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 14 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'avar khaganate', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 12 artykułów z abstraktami dla słów kluczowych: 'avar khaganate'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'lombard italy'...
#   > Wysyłane parametry: {'keywords': 'lombard italy', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'lombard italy', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'lombard italy', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 3.
# Pobrano 135 artykułów z abstraktami dla słów kluczowych: 'lombard italy'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'cassiodorus'...
#   > Wysyłane parametry: {'keywords': 'cassiodorus', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 28 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'cassiodorus', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 19 artykułów z abstraktami dla słów kluczowych: 'cassiodorus'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'jordanes'...
#   > Wysyłane parametry: {'keywords': 'jordanes', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 45 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'jordanes', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 36 artykułów z abstraktami dla słów kluczowych: 'jordanes'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'gregory of tours'...
#   > Wysyłane parametry: {'keywords': 'gregory of tours', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'gregory of tours', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 29 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'gregory of tours', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 3 (koniec).
# Pobrano 70 artykułów z abstraktami dla słów kluczowych: 'gregory of tours'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'isidore of seville'...
#   > Wysyłane parametry: {'keywords': 'isidore of seville', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'isidore of seville', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 42 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'isidore of seville', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 3 (koniec).
# Pobrano 64 artykułów z abstraktami dla słów kluczowych: 'isidore of seville'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'roman law codification'...
#   > Wysyłane parametry: {'keywords': 'roman law codification', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'roman law codification', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 33 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'roman law codification', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 3 (koniec).
# Pobrano 69 artykułów z abstraktami dla słów kluczowych: 'roman law codification'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'theodosian code'...
#   > Wysyłane parametry: {'keywords': 'theodosian code', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 17 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'theodosian code', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 12 artykułów z abstraktami dla słów kluczowych: 'theodosian code'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'salic law'...
#   > Wysyłane parametry: {'keywords': 'salic law', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 15 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'salic law', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 10 artykułów z abstraktami dla słów kluczowych: 'salic law'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'gothic spain'...
#   > Wysyłane parametry: {'keywords': 'gothic spain', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'gothic spain', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'gothic spain', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 3.
# Pobrano 131 artykułów z abstraktami dla słów kluczowych: 'gothic spain'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'alan kingdom'...
#   > Wysyłane parametry: {'keywords': 'alan kingdom', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'alan kingdom', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'alan kingdom', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 3.
# Pobrano 17 artykułów z abstraktami dla słów kluczowych: 'alan kingdom'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'vandal africa'...
#   > Wysyłane parametry: {'keywords': 'vandal africa', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 17 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'vandal africa', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 15 artykułów z abstraktami dla słów kluczowych: 'vandal africa'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'roman identity 5th-7th'...
#   > Wysyłane parametry: {'keywords': 'roman identity 5th-7th', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 2 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'roman identity 5th-7th', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 2 artykułów z abstraktami dla słów kluczowych: 'roman identity 5th-7th'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'early medieval history'...
#   > Wysyłane parametry: {'keywords': 'early medieval history', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Błąd parsowania rekordu: 'NoneType' object has no attribute 'get'
#   > Wysyłane parametry: {'keywords': 'early medieval history', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'early medieval history', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 3.
# Pobrano 122 artykułów z abstraktami dla słów kluczowych: 'early medieval history'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'barbarian migrations'...
#   > Wysyłane parametry: {'keywords': 'barbarian migrations', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 11 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'barbarian migrations', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 9 artykułów z abstraktami dla słów kluczowych: 'barbarian migrations'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'vikings'...
#   > Wysyłane parametry: {'keywords': 'vikings', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'vikings', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'vikings', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 3.
# Pobrano 117 artykułów z abstraktami dla słów kluczowych: 'vikings'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'carolingian'...
#   > Wysyłane parametry: {'keywords': 'carolingian', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'carolingian', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'carolingian', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 3.
# Pobrano 109 artykułów z abstraktami dla słów kluczowych: 'carolingian'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'merovingian'...
#   > Wysyłane parametry: {'keywords': 'merovingian', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'merovingian', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 49 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'merovingian', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 3 (koniec).
# Pobrano 76 artykułów z abstraktami dla słów kluczowych: 'merovingian'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'early middle ages'...
#   > Wysyłane parametry: {'keywords': 'early middle ages', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'early middle ages', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'early middle ages', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 3.
# Pobrano 86 artykułów z abstraktami dla słów kluczowych: 'early middle ages'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'byzantium'...
#   > Wysyłane parametry: {'keywords': 'byzantium', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'byzantium', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'byzantium', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 3.
# Pobrano 75 artykułów z abstraktami dla słów kluczowych: 'byzantium'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'dark ages'...
#   > Wysyłane parametry: {'keywords': 'dark ages', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'dark ages', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'dark ages', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 3.
# Pobrano 108 artykułów z abstraktami dla słów kluczowych: 'dark ages'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'anglo-saxon history'...
#   > Wysyłane parametry: {'keywords': 'anglo-saxon history', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'anglo-saxon history', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'anglo-saxon history', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 3.
# Pobrano 131 artykułów z abstraktami dla słów kluczowych: 'anglo-saxon history'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'saxons'...
#   > Wysyłane parametry: {'keywords': 'saxons', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'saxons', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'saxons', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 3.
# Pobrano 132 artykułów z abstraktami dla słów kluczowych: 'saxons'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'angles in britannia'...
#   > Wysyłane parametry: {'keywords': 'angles in britannia', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 1 (koniec).
# Pobrano 0 artykułów z abstraktami dla słów kluczowych: 'angles in britannia'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'jutes'...
#   > Wysyłane parametry: {'keywords': 'jutes', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 9 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'jutes', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 7 artykułów z abstraktami dla słów kluczowych: 'jutes'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'early slavs'...
#   > Wysyłane parametry: {'keywords': 'early slavs', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'early slavs', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'early slavs', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 3.
# Pobrano 126 artykułów z abstraktami dla słów kluczowych: 'early slavs'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'romano-britons'...
#   > Wysyłane parametry: {'keywords': 'romano-britons', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 2 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'romano-britons', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 1 artykułów z abstraktami dla słów kluczowych: 'romano-britons'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'romano-british'...
#   > Wysyłane parametry: {'keywords': 'romano-british', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'romano-british', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'romano-british', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 3.
# Pobrano 134 artykułów z abstraktami dla słów kluczowych: 'romano-british'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'huns history'...
#   > Wysyłane parametry: {'keywords': 'huns history', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'huns history', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'huns history', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 5 rekordów na stronie 3.
# Pobrano 85 artykułów z abstraktami dla słów kluczowych: 'huns history'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'history huns'...
#   > Wysyłane parametry: {'keywords': 'history huns', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'history huns', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'history huns', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 5 rekordów na stronie 3.
# Pobrano 85 artykułów z abstraktami dla słów kluczowych: 'history huns'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'white huns'...
#   > Wysyłane parametry: {'keywords': 'white huns', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 4 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'white huns', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 3 artykułów z abstraktami dla słów kluczowych: 'white huns'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'black huns'...
#   > Wysyłane parametry: {'keywords': 'black huns', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 30 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'black huns', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 25 artykułów z abstraktami dla słów kluczowych: 'black huns'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'goths'...
#   > Wysyłane parametry: {'keywords': 'goths', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'goths', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'goths', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 3.
# Pobrano 124 artykułów z abstraktami dla słów kluczowych: 'goths'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'ostrogoths'...
#   > Wysyłane parametry: {'keywords': 'ostrogoths', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 30 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'ostrogoths', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 20 artykułów z abstraktami dla słów kluczowych: 'ostrogoths'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'visigoths'...
#   > Wysyłane parametry: {'keywords': 'visigoths', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'visigoths', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 9 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'visigoths', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 3 (koniec).
# Pobrano 40 artykułów z abstraktami dla słów kluczowych: 'visigoths'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'history franks'...
#   > Wysyłane parametry: {'keywords': 'history franks', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'history franks', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'history franks', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 26 rekordów na stronie 3.
# Pobrano 119 artykułów z abstraktami dla słów kluczowych: 'history franks'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'franks history'...
#   > Wysyłane parametry: {'keywords': 'franks history', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'franks history', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'franks history', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 26 rekordów na stronie 3.
# Pobrano 119 artykułów z abstraktami dla słów kluczowych: 'franks history'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'alemanni history'...
#   > Wysyłane parametry: {'keywords': 'alemanni history', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 3 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'alemanni history', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 3 artykułów z abstraktami dla słów kluczowych: 'alemanni history'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'history alemanni'...
#   > Wysyłane parametry: {'keywords': 'history alemanni', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 3 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'history alemanni', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 3 artykułów z abstraktami dla słów kluczowych: 'history alemanni'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'vandals history'...
#   > Wysyłane parametry: {'keywords': 'vandals history', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 22 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'vandals history', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 19 artykułów z abstraktami dla słów kluczowych: 'vandals history'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'gepids'...
#   > Wysyłane parametry: {'keywords': 'gepids', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 16 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'gepids', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 11 artykułów z abstraktami dla słów kluczowych: 'gepids'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'lombards'...
#   > Wysyłane parametry: {'keywords': 'lombards', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 48 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'lombards', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 39 artykułów z abstraktami dla słów kluczowych: 'lombards'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'attila'...
#   > Wysyłane parametry: {'keywords': 'attila', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'attila', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'attila', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 3.
# Pobrano 32 artykułów z abstraktami dla słów kluczowych: 'attila'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'thuringians'...
#   > Wysyłane parametry: {'keywords': 'thuringians', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 1 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'thuringians', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 1 artykułów z abstraktami dla słów kluczowych: 'thuringians'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'rugians'...
#   > Wysyłane parametry: {'keywords': 'rugians', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 1 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'rugians', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 0 artykułów z abstraktami dla słów kluczowych: 'rugians'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'sciri'...
#   > Wysyłane parametry: {'keywords': 'sciri', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 31 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'sciri', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 30 artykułów z abstraktami dla słów kluczowych: 'sciri'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'herules'...
#   > Wysyłane parametry: {'keywords': 'herules', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 2 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'herules', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 1 artykułów z abstraktami dla słów kluczowych: 'herules'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'bavarians history'...
#   > Wysyłane parametry: {'keywords': 'bavarians history', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 3 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'bavarians history', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 3 artykułów z abstraktami dla słów kluczowych: 'bavarians history'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'avars history'...
#   > Wysyłane parametry: {'keywords': 'avars history', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'avars history', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 1 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'avars history', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 3 (koniec).
# Pobrano 37 artykułów z abstraktami dla słów kluczowych: 'avars history'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'burgundians'...
#   > Wysyłane parametry: {'keywords': 'burgundians', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 10 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'burgundians', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 8 artykułów z abstraktami dla słów kluczowych: 'burgundians'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'viking'...
#   > Wysyłane parametry: {'keywords': 'viking', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'viking', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'viking', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 3.
#   > Błąd parsowania rekordu: 'NoneType' object has no attribute 'get'
# Pobrano 118 artykułów z abstraktami dla słów kluczowych: 'viking'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'germanic paganism'...
#   > Wysyłane parametry: {'keywords': 'germanic paganism', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 10 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'germanic paganism', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 7 artykułów z abstraktami dla słów kluczowych: 'germanic paganism'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'slavic paganism'...
#   > Wysyłane parametry: {'keywords': 'slavic paganism', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 42 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'slavic paganism', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 32 artykułów z abstraktami dla słów kluczowych: 'slavic paganism'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'medieval celts'...
#   > Wysyłane parametry: {'keywords': 'medieval celts', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 9 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'medieval celts', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 6 artykułów z abstraktami dla słów kluczowych: 'medieval celts'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'norse paganism'...
#   > Wysyłane parametry: {'keywords': 'norse paganism', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 3 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'norse paganism', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 3 artykułów z abstraktami dla słów kluczowych: 'norse paganism'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'foederati'...
#   > Wysyłane parametry: {'keywords': 'foederati', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 12 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'foederati', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 10 artykułów z abstraktami dla słów kluczowych: 'foederati'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'roman britannia'...
#   > Wysyłane parametry: {'keywords': 'roman britannia', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 35 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'roman britannia', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 32 artykułów z abstraktami dla słów kluczowych: 'roman britannia'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'suebi history'...
#   > Wysyłane parametry: {'keywords': 'suebi history', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 2 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'suebi history', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 2 artykułów z abstraktami dla słów kluczowych: 'suebi history'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'alans history'...
#   > Wysyłane parametry: {'keywords': 'alans history', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'alans history', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 16 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'alans history', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 3 (koniec).
# Pobrano 58 artykułów z abstraktami dla słów kluczowych: 'alans history'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'history alans'...
#   > Wysyłane parametry: {'keywords': 'history alans', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'history alans', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 16 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'history alans', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 3 (koniec).
# Pobrano 58 artykułów z abstraktami dla słów kluczowych: 'history alans'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'frisians'...
#   > Wysyłane parametry: {'keywords': 'frisians', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 22 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'frisians', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 18 artykułów z abstraktami dla słów kluczowych: 'frisians'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'sarmatians'...
#   > Wysyłane parametry: {'keywords': 'sarmatians', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'sarmatians', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'sarmatians', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 3.
# Pobrano 124 artykułów z abstraktami dla słów kluczowych: 'sarmatians'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'period 400-1000'...
#   > Wysyłane parametry: {'keywords': 'period 400-1000', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'period 400-1000', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'period 400-1000', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 3.
# Pobrano 135 artykułów z abstraktami dla słów kluczowych: 'period 400-1000'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'late roman empire'...
#   > Wysyłane parametry: {'keywords': 'late roman empire', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'late roman empire', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'late roman empire', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 3.
# Pobrano 123 artykułów z abstraktami dla słów kluczowych: 'late roman empire'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'barbarian kingdoms'...
#   > Wysyłane parametry: {'keywords': 'barbarian kingdoms', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 29 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'barbarian kingdoms', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 20 artykułów z abstraktami dla słów kluczowych: 'barbarian kingdoms'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'arianism christianity'...
#   > Wysyłane parametry: {'keywords': 'arianism christianity', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 18 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'arianism christianity', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 16 artykułów z abstraktami dla słów kluczowych: 'arianism christianity'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'magyars'...
#   > Wysyłane parametry: {'keywords': 'magyars', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Błąd parsowania rekordu: 'NoneType' object has no attribute 'get'
#   > Wysyłane parametry: {'keywords': 'magyars', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 4 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'magyars', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
# ...
#   > Wysyłane parametry: {'keywords': 'majorian', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 1 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'majorian', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 1 artykułów z abstraktami dla słów kluczowych: 'majorian'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'aegidius'...
#   > Wysyłane parametry: {'keywords': 'aegidius', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 33 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'aegidius', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 22 artykułów z abstraktami dla słów kluczowych: 'aegidius'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'syagrius'...
#   > Wysyłane parametry: {'keywords': 'syagrius', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 1 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'syagrius', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 1 artykułów z abstraktami dla słów kluczowych: 'syagrius'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'crisis of third century'...
#   > Wysyłane parametry: {'keywords': 'crisis of third century', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'crisis of third century', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'crisis of third century', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 3.
# Pobrano 141 artykułów z abstraktami dla słów kluczowych: 'crisis of third century'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'constantine the great'...
#   > Wysyłane parametry: {'keywords': 'constantine the great', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'constantine the great', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'constantine the great', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 3.
# Pobrano 121 artykułów z abstraktami dla słów kluczowych: 'constantine the great'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'catalaunian plains'...
#   > Wysyłane parametry: {'keywords': 'catalaunian plains', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 2 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'catalaunian plains', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 2 artykułów z abstraktami dla słów kluczowych: 'catalaunian plains'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'ripuarian franks'...
#   > Wysyłane parametry: {'keywords': 'ripuarian franks', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 1 (koniec).
# Pobrano 0 artykułów z abstraktami dla słów kluczowych: 'ripuarian franks'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'salian franks'...
#   > Wysyłane parametry: {'keywords': 'salian franks', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 1 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'salian franks', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 1 artykułów z abstraktami dla słów kluczowych: 'salian franks'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'ammianus marcellinus'...
#   > Wysyłane parametry: {'keywords': 'ammianus marcellinus', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'ammianus marcellinus', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 28 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'ammianus marcellinus', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 3 (koniec).
# Pobrano 61 artykułów z abstraktami dla słów kluczowych: 'ammianus marcellinus'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'burgundy history'...
#   > Wysyłane parametry: {'keywords': 'burgundy history', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'burgundy history', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'burgundy history', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 3.
# Pobrano 142 artykułów z abstraktami dla słów kluczowych: 'burgundy history'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'history burgundy'...
#   > Wysyłane parametry: {'keywords': 'history burgundy', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'history burgundy', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'history burgundy', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 3.
# Pobrano 142 artykułów z abstraktami dla słów kluczowych: 'history burgundy'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'strategikon'...
#   > Wysyłane parametry: {'keywords': 'strategikon', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 7 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'strategikon', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 6 artykułów z abstraktami dla słów kluczowych: 'strategikon'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'roxolani'...
#   > Wysyłane parametry: {'keywords': 'roxolani', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 9 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'roxolani', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 7 artykułów z abstraktami dla słów kluczowych: 'roxolani'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'iazyges'...
#   > Wysyłane parametry: {'keywords': 'iazyges', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 7 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'iazyges', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 6 artykułów z abstraktami dla słów kluczowych: 'iazyges'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'sabirs'...
#   > Wysyłane parametry: {'keywords': 'sabirs', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 10 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'sabirs', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 9 artykułów z abstraktami dla słów kluczowych: 'sabirs'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'onoghurs'...
#   > Wysyłane parametry: {'keywords': 'onoghurs', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 1 (koniec).
# Pobrano 0 artykułów z abstraktami dla słów kluczowych: 'onoghurs'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'utigurs'...
#   > Wysyłane parametry: {'keywords': 'utigurs', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 2 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'utigurs', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 1 artykułów z abstraktami dla słów kluczowych: 'utigurs'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'kutrigurs'...
#   > Wysyłane parametry: {'keywords': 'kutrigurs', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 2 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'kutrigurs', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 1 artykułów z abstraktami dla słów kluczowych: 'kutrigurs'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'akatziri'...
#   > Wysyłane parametry: {'keywords': 'akatziri', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 2 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'akatziri', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 2 artykułów z abstraktami dla słów kluczowych: 'akatziri'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'barsils'...
#   > Wysyłane parametry: {'keywords': 'barsils', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 2 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'barsils', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 2 artykułów z abstraktami dla słów kluczowych: 'barsils'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'mishar tatars'...
#   > Wysyłane parametry: {'keywords': 'mishar tatars', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 23 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'mishar tatars', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 17 artykułów z abstraktami dla słów kluczowych: 'mishar tatars'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'mordvins'...
#   > Wysyłane parametry: {'keywords': 'mordvins', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'mordvins', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 45 rekordów na stronie 2.
#   > Błąd parsowania rekordu: 'NoneType' object has no attribute 'get'
#   > Wysyłane parametry: {'keywords': 'mordvins', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 3 (koniec).
# Pobrano 71 artykułów z abstraktami dla słów kluczowych: 'mordvins'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'qaraqalpaqs'...
#   > Wysyłane parametry: {'keywords': 'qaraqalpaqs', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 1 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'qaraqalpaqs', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 1 artykułów z abstraktami dla słów kluczowych: 'qaraqalpaqs'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'nogai horde'...
#   > Wysyłane parametry: {'keywords': 'nogai horde', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'nogai horde', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 27 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'nogai horde', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 3 (koniec).
# Pobrano 67 artykułów z abstraktami dla słów kluczowych: 'nogai horde'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'bashkirs'...
#   > Wysyłane parametry: {'keywords': 'bashkirs', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'bashkirs', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 2.
#   > Wysyłane parametry: {'keywords': 'bashkirs', 'size': 50, 'page': 3, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 50 rekordów na stronie 3.
# Pobrano 104 artykułów z abstraktami dla słów kluczowych: 'bashkirs'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'tengrism'...
#   > Wysyłane parametry: {'keywords': 'tengrism', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 35 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'tengrism', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 24 artykułów z abstraktami dla słów kluczowych: 'tengrism'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'uyghur khaganate'...
#   > Wysyłane parametry: {'keywords': 'uyghur khaganate', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 20 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'uyghur khaganate', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 13 artykułów z abstraktami dla słów kluczowych: 'uyghur khaganate'.
# Rozpoczynam pobieranie dla słów kluczowych (Search API): 'yenisei kyrgyz'...
#   > Wysyłane parametry: {'keywords': 'yenisei kyrgyz', 'size': 50, 'page': 1, 'openAccessColor': 'gold', 'format': 'json'}
#   > Znaleziono 40 rekordów na stronie 1.
#   > Wysyłane parametry: {'keywords': 'yenisei kyrgyz', 'size': 50, 'page': 2, 'openAccessColor': 'gold', 'format': 'json'}
#   > Brak dalszych wyników na stronie 2 (koniec).
# Pobrano 25 artykułów z abstraktami dla słów kluczowych: 'yenisei kyrgyz'.
#
# Gotowe! Zapisano łącznie 12473 artykułów do pliku: openaire_articles_updated.csv
# Przykładowe dane:
#   keywords                                              title  \
# 0  ayyubid  II. Gıyaseddin Keyhüsrev Döneminde Türkiye Sel...
# 1  ayyubid  The Ayyubids in Yemen: Their Political History...
# 2  ayyubid  Endowments and their spending on schools in Eg...
# 3  ayyubid  Manifestations of unity and diversity between ...
# 4  ayyubid  Scientific and literary activity in the era of...
#
#                                              creator  \
# 0                                      YASEMİN AKTAŞ
# 1                                 Mahmood AlTikreety
# 2                                    Juman Eid Juman
# 3  null Muhammad Mahmoud Taha; null Fayez Ali Bakhit
# 4                                       Nazim Rashed
#
#                                             abstract  year journal_title  \
# 0  The first meetings between Turkey Seljuk State...  2015
# 1  The Ayyubid state became able, during the reig...  1980
# 2  The Ayyubid era in Egypt witnessed a scientifi...  2021
# 3                                          <jats:p/>  2022
# 4  Salah al-Din al-Ayyubi reigned Egypt in the ye...  1977
#
#   license                                       link    query
# 0    OPEN  https://doi.org/10.17719/jisr.20153913747  ayyubid
# 1    OPEN                                             ayyubid
# 2    OPEN                                             ayyubid
# 3    OPEN  https://doi.org/10.33899/berj.2022.176451  ayyubid
# 4    OPEN                                             ayyubid

# %% [markdown]
# # quickfix

# %%
import pandas as pd
import re

# 1. Wczytanie obecnego pliku
input_file = "openaire_articles_updated.csv"
output_file = "openaire_articles_updated_fixed.csv"

print(f"Wczytuję {input_file}...")
try:
    df = pd.read_csv(input_file)
    initial_count = len(df)
    print(f"Liczba wierszy na start: {initial_count}")
except FileNotFoundError:
    print("Nie znaleziono pliku wejściowego!")
    df = pd.DataFrame()

if not df.empty:
    # 2. Usuwanie tagów HTML/XML (Quickfix)
    ### wyrażenie r'<[^>]+>' oznacza: znajdź "<", potem cokolwiek co NIE jest ">", aż do zamknięcia ">"
    def clean_tags(text):
        if isinstance(text, str):
            return re.sub(r'<[^>]+>', '', text)
        return text

    print("Usuwam tagi HTML/XML z tytułów i abstraktów...")
    cols_to_clean = ['title', 'abstract']
    for col in cols_to_clean:
        if col in df.columns:
            df[col] = df[col].apply(clean_tags)

    # 3. Deduplikacja
    ### usuwanie duplikatów sprawdzając tylko kombinację tytuł+autor+abstrakt
    ### keep='first' -> zostawia pierwsze wystąpienie (z pierwszym przypisanym keywordem), resztę usuwa
    print("Rozpoczynam deduplikację...")
    df = df.drop_duplicates(subset=['title', 'creator', 'abstract'], keep='first')
    
    final_count = len(df)
    print(f"Usunięto {initial_count - final_count} duplikatów.")
    print(f"Liczba unikalnych artykułów: {final_count}")

    # 4. Zapis
    df.to_csv(output_file, index=False, encoding='utf-8')
    print(f"\nZapisano czysty plik: {output_file}")
    
    ## podgląd po czyszczeniu
    print("\nPrzykładowy wyczyszczony abstrakt:")
    print(df['abstract'].iloc[0][:200] + "...")
